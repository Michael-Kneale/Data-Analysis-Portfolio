# %% [markdown]
# # Mobile Customer Churn
#
# In this Portfolio task you will work with some (fake but realistic) data on Mobile Customer Churn.  Churn is where
# a customer leaves the mobile provider.   The goal is to build a simple predictive model to predict churn from available features.
#
# The data was generated (by Hume Winzar at Macquarie) based on a real dataset provided by Optus.  The data is simulated but the column headings are the same. (Note that I'm not sure if all of the real relationships in this data are preserved so you need to be cautious in interpreting the results of your analysis here).
#
# The data is provided in file `MobileCustomerChurn.csv` and column headings are defined in a file `MobileChurnDataDictionary.csv` (store these in the `files` folder in your project).
#
# Your high level goal in this notebook is to try to build and evaluate a __predictive model for churn__ - predict the value of the CHURN_IND field in the data from some of the other fields.  Note that the three `RECON` fields should not be used as they indicate whether the customer reconnected after having churned.
#
# __Note:__ you are not being evaluated on the _accuracy_ of the model but on the _process_ that you use to generate it.  You can use a simple model such as Logistic Regression for this task or try one of the more advanced methods covered in recent weeks.  Explore the data, build a model using a selection of features and then do some work on finding out which features provide the most accurate results.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
# %matplotlib inline

# %%
churn = pd.read_csv("files/MobileCustomerChurn.csv", na_values=["NA", "#VALUE!"], index_col='INDEX')
churn.head()
# Out:
#        CUST_ID  ACCOUNT_TENURE  ACCT_CNT_SERVICES   AGE       CFU  \
# INDEX
# 1            1              46                  1  30.0  CONSUMER
# 2            2              60                  3  55.0  CONSUMER
# 3            5              65                  1  29.0  CONSUMER
# 4            6              31                  1  51.0  CONSUMER
# 5            8              95                  1  31.0  CONSUMER
#
#        SERVICE_TENURE  PLAN_ACCESS_FEE BYO_PLAN_STATUS  PLAN_TENURE  \
# INDEX
# 1                  46            54.54         NON BYO           15
# 2                  59            54.54         NON BYO            5
# 3                  65            40.90             BYO           15
# 4                  31            31.81         NON BYO           31
# 5                  95            54.54         NON BYO            0
#
#        MONTHS_OF_CONTRACT_REMAINING  ...  CONTRACT_STATUS  \
# INDEX                                ...
# ...

# %%
#Remove the RECON fields using the drop function
churn = churn.drop(columns=['RECON_SMS_NEXT_MTH', 'RECON_TELE_NEXT_MTH', 'RECON_EMAIL_NEXT_MTH'])
churn.head()
# Out:
#        CUST_ID  ACCOUNT_TENURE  ACCT_CNT_SERVICES   AGE       CFU  \
# INDEX
# 1            1              46                  1  30.0  CONSUMER
# 2            2              60                  3  55.0  CONSUMER
# 3            5              65                  1  29.0  CONSUMER
# 4            6              31                  1  51.0  CONSUMER
# 5            8              95                  1  31.0  CONSUMER
#
#        SERVICE_TENURE  PLAN_ACCESS_FEE BYO_PLAN_STATUS  PLAN_TENURE  \
# INDEX
# 1                  46            54.54         NON BYO           15
# 2                  59            54.54         NON BYO            5
# 3                  65            40.90             BYO           15
# 4                  31            31.81         NON BYO           31
# 5                  95            54.54         NON BYO            0
#
#        MONTHS_OF_CONTRACT_REMAINING  LAST_FX_CONTRACT_DURATION  \
# INDEX
# 1                                 0                         24
# ...

# %%
#Remove any outliers

#Replace infinite values with nan values, so that the dropna() function eliminates all nan and infinite values
churn.replace([np.inf, -np.inf], np.nan, inplace=True)
churn.dropna()

#Remove data points that are outside 1.5 times the interquartile range of Q3 - Q1
Q1 = churn.quantile(0.25)
Q3 = churn.quantile(0.75)
IQR = Q3 - Q1
churn = churn[~((churn < (Q1 - 1.5 * IQR)) |(churn > (Q3 + 1.5 * IQR))).any(axis=1)]
# Out:
# <ipython-input-4-9ef94e77727e>:11: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   churn = churn[~((churn < (Q1 - 1.5 * IQR)) |(churn > (Q3 + 1.5 * IQR))).any(axis=1)]
# <ipython-input-4-9ef94e77727e>:11: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   churn = churn[~((churn < (Q1 - 1.5 * IQR)) |(churn > (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
#Logistic regression

#Use the following columns as potential indicators for the variable we want to predict i.e. CHURN_IND
feature_columns = ['ACCOUNT_TENURE', 'ACCT_CNT_SERVICES', 'SERVICE_TENURE', 'PLAN_ACCESS_FEE', 'PLAN_TENURE', 'LAST_FX_CONTRACT_DURATION', 'PREV_CONTRACT_DURATION', 'MONTHLY_SPEND']
X = churn[feature_columns]
Y = churn.CHURN_IND

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.25, random_state = 0)

#Perform a logistic regression, and create a confusion matrix, using the training and testing data
regression = LogisticRegression()
regression.fit(X_train, Y_train)
Y_pred = regression.predict(X_test)
conf_matrix = metrics.confusion_matrix(Y_test, Y_pred)

# %%
#Visualise data using heatmap

class_names = [0,1]
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)

#Create a heatmap using the confusion matrix with the numbers shown on each square. Use integer formatting
sns.heatmap(pd.DataFrame(conf_matrix), annot = True, fmt = "g")
#Give the heatmap labels and a title
plt.title("Confusion Matrix", y = 1.1)
plt.ylabel("Actual Label")
plt.xlabel("Predicted Label")
#Print the accuracy and precision statistics
print("Accuracy:", metrics.accuracy_score(Y_test, Y_pred))
print("Precision:", metrics.precision_score(Y_test, Y_pred))
# Out:
# Accuracy: 0.7090859703925031
# Precision: 0.6397459165154264

# %%
#Discussion
print("The model has an accuracy score of approximately 0.71, meaning it is reasonably accurate.\n"
      "It also has a precision score of approximately 0.64 i.e. it correctly predicts the churn\n"
      "64% of the time. Looking at the numbers, the true positives (the top left corner) far\n"
      "outnumber the false positives (the top right corner), being 4516 and 397 respectively.\n"
      "However, the number of true negatives is actually far less than the number of false\n"
      "negatives, being 705 and 1745 respectively. In other words, the model is quite likely\n"
      "to predict a customer as not having disconnected from their service when in fact they did.\n"
      "Overall, there model has room for improvement but it is still fairly useful.")
